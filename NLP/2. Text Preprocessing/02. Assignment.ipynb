# %% [markdown]
# # **02. Assignment**
# ---
#
#
# ### 🧑‍💼 **Shuvendu Pritam Das**
# *Data Science / ML Enthusiast*
#
# - **GitHub:** [SPritamDas](https://github.com/SPritamDas/My-Profile)
# - **LinkedIn:** [Shuvendu Pritam Das](https://www.linkedin.com/in/shuvendupritamdas/)
# - **Email:** shuvendupritamdas181@gmail.com
# ---

# %% [markdown]
# # Dataset Creation using API

# %% [markdown]
# 157b6a28d7dbb3135aabc0470c1625f4
#
# ---
#
# eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxNTdiNmEyOGQ3ZGJiMzEzNWFhYmMwNDcwYzE2MjVmNCIsIm5iZiI6MTcyOTcwNTk2OS4yODcxNDYsInN1YiI6IjY3MTkzNzAyNWQwZGU4OTA0MmQ4Y2JiZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Ho3SioBcuYCTnNOCohqs2sDgi2ANIbzxuUBuUCv69TU
#
# ---

# %%
import requests
import pandas as pd

# %%
# Define the API URL for top-rated movies
api_key = "157b6a28d7dbb3135aabc0470c1625f4"  # Your API key
url = f"https://api.themoviedb.org/3/movie/top_rated?api_key={api_key}&language=en-US&page=1"

# Send a GET request to the API URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    print(data)  # Print the JSON data
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg', 'genre_ids': [18, 80], 'id': 278, 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.', 'popularity': 219.372, 'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg', 'release_date': '1994-09-23', 'title': 'The Shawshank Redemption', 'video': False, 'vote_average': 8.707, 'vote_count': 26996}, {'adult': False, 'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg', 'genre_ids': [18, 80], 'id': 238, 'original_language': 'en', 'original_title': 'The Godfather', 'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.', 'popularity': 192.572, 'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg', 'release_date': '1972-03-14', 'title': 'The Godfather', 'video': False, 'vote_average': 8.7, 'vote_count': 20501}, {'adult': False, 'backdrop_path': '/417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg', 'genre_ids': [16, 878, 10751], 'id': 1184918, 'original_language': 'en', 'original_title': 'The Wild Robot', 'overview': "After a shipwreck, an intelligent robot called Roz is stranded on an uninhabited island. To survive the harsh environment, Roz bonds with the island's animals and cares for an orphaned baby goose.", 'popularity': 5200.959, 'poster_path': '/wTnV3PCVW5O92JMrFvvrRcV39RU.jpg', 'release_date': '2024-09-12', 'title': 'The Wild Robot', 'video': False, 'vote_average': 8.662, 'vote_count': 1289}, {'adult': False, 'backdrop_path': '/kGzFbGhp99zva6oZODW5atUtnqi.jpg', 'genre_ids': [18, 80], 'id': 240, 'original_language': 'en', 'original_title': 'The Godfather Part II', 'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.', 'popularity': 97.101, 'poster_path': '/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg', 'release_date': '1974-12-20', 'title': 'The Godfather Part II', 'video': False, 'vote_average': 8.6, 'vote_count': 12367}, {'adult': False, 'backdrop_path': '/zb6fM1CX41D9rF9hdgclu0peUmy.jpg', 'genre_ids': [18, 36, 10752], 'id': 424, 'original_language': 'en', 'original_title': "Schindler's List", 'overview': 'The true story of how businessman Oskar Schindler saved over a thousand Jewish lives from the Nazis while they worked as slaves in his factory during World War II.', 'popularity': 86.69, 'poster_path': '/sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg', 'release_date': '1993-12-15', 'title': "Schindler's List", 'video': False, 'vote_average': 8.565, 'vote_count': 15772}, {'adult': False, 'backdrop_path': '/qqHQsStV6exghCM7zbObuYBiYxw.jpg', 'genre_ids': [18], 'id': 389, 'original_language': 'en', 'original_title': '12 Angry Men', 'overview': "The defense and the prosecution have rested and the jury is filing into the jury room to decide if a young Spanish-American is guilty or innocent of murdering his father. What begins as an open and shut case soon becomes a mini-drama of each of the jurors' prejudices and preconceptions about the trial, the accused, and each other.", 'popularity': 59.426, 'poster_path': '/ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg', 'release_date': '1957-04-10', 'title': '12 Angry Men', 'video': False, 'vote_average': 8.5, 'vote_count': 8581}, {'adult': False, 'backdrop_path': '/6oaL4DP75yABrd5EbC4H2zq5ghc.jpg', 'genre_i ...

# %% [markdown]
# **Remarks:**
# - Total number of web pages = 485

# %%
data = pd.DataFrame(data)
data.head()
# Out:
#    page                                            results  total_pages  \
# 0     1  {'adult': False, 'backdrop_path': '/zfbjgQE1uS...          485
# 1     1  {'adult': False, 'backdrop_path': '/tmU7GeKVyb...          485
# 2     1  {'adult': False, 'backdrop_path': '/417tYZ4XUy...          485
# 3     1  {'adult': False, 'backdrop_path': '/kGzFbGhp99...          485
# 4     1  {'adult': False, 'backdrop_path': '/zb6fM1CX41...          485
#
#    total_results
# 0           9690
# 1           9690
# 2           9690
# 3           9690
# 4           9690

# %% [markdown]
# #### Using For loop to extract data from each page

# %%
import requests
import pandas as pd

# Define your API key
api_key = "157b6a28d7dbb3135aabc0470c1625f4"  # Replace with your API key

# Initialize an empty DataFrame to hold all the movie data
data = pd.DataFrame()

# Loop through the pages
for i in range(1, 485):  # TMDb has a maximum of 485 pages for top-rated movies
    # Fetch data from the API
    response = requests.get(f"https://api.themoviedb.org/3/movie/top_rated?api_key={api_key}&language=en-US&page={i}")

    # Check if the request was successful
    if response.status_code == 200:
        # Convert the JSON response to a DataFrame
        temp_data = pd.DataFrame(response.json()['results'])

        # Concatenate the new data with the existing data
        data = pd.concat([data, temp_data], ignore_index=True)
    else:
        print(f"Failed to retrieve data from page {i}. Status code: {response.status_code}")
        break  # Stop if any page fails

# %% [markdown]
# # Exploring Data Set

# %%
data.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]      278
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]      238
# 2  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 3  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]      240
# 4  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]      424
#
#   original_language            original_title  \
# 0                en  The Shawshank Redemption
# 1                en             The Godfather
# 2                en            The Wild Robot
# 3                en     The Godfather Part II
# 4                en          Schindler's List
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     219.372
# 1  Spanning the years 1945 to 1955, a chronicle o...     192.572
# 2  After a shipwreck, an intelligent robot called...    5200.959
# 3  In the continuing saga of the Corleone crime f...      97.101
# 4  The true story of how businessman Oskar Schind...      86.690
#
#                         poster_path release_date                     title  \
# 0  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
# 2  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12            The Wild Robot
# 3  /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20     The Godfather Part II
# 4  /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15          Schindler's List
#
#    video  vote_average  vote_count
# 0  False         8.707       26996
# 1  False         8.700       20501
# 2  False         8.662        1289
# 3  False         8.600       12367
# 4  False         8.565       15772

# %%
data.shape
# Out:
# (9680, 14)

# %%
data.isnull().sum()
# Out:
# adult                0
# backdrop_path        9
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# overview             0
# popularity           0
# poster_path          5
# release_date         0
# title                0
# video                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
data['original_title'].duplicated().sum()
# Out:
# 362

# %%
data['title'].duplicated().sum()
# Out:
# 438

# %%
data['title'].value_counts()
# Out:
# title
# Return                                    10
# Pinocchio                                  4
# Beauty and the Beast                       4
# King Kong                                  3
# Extinction                                 3
#                                           ..
# Shattered Glass                            1
# The Full Monty                             1
# Ichi the Killer                            1
# Lyle, Lyle, Crocodile                      1
# Star Trek VI: The Undiscovered Country     1
# Name: count, Length: 9242, dtype: int64

# %%
data[data['title']=='Return']
# Out:
#       adult                     backdrop_path        genre_ids       id  \
# 4849  False                              None        [16, 878]   839321
# 5301  False                              None               []   348877
# 5644  False  /h4SIEXZcj5tY9w8mEWendCZJ1kE.jpg             [35]   464446
# 5874  False                              None         [18, 14]   670355
# 5981  False                              None             [18]   320367
# 5994  False  /dJ52jV7HlJ9hB8kdBOnj01DllBA.jpg             [18]    82520
# 6405  False                              None             [18]  1086372
# 6464  False                              None             [27]   379862
# 6467  False                              None             [16]   836466
# 7462  False  /tu5IcNPo99rJkIgNwKZqPYQ2MiY.jpg  [27, 14, 10749]   403587
#
#      original_language original_title  \
# 4849                pl         Powrót
# 5301                en         Return
# 5644                en         Return
# 5874                en         Return
# 5981                en         Return
# 5994                en         Return
# 6405                hy       Վերադարձ
# 6464                en         Return
# 6467                en         Return
# 7462                en         Return
#
#                                                overview  popularity  \
# 4849  Polish animator Anna Błaszczyk’s humorous shor...       7.926
# 5301  Static images of an old country house are comb...       3.754
# 5644  A young man returns home for the weekend to di...       5.164
# 5874  Owen, a young man is dissatisfied with his lif...       4.799
# 5981  A tale of terror. Cathy Reed has been institut...       6.819
# 5994  Back from a tour of duty, Kelli struggles to f...       9.149
# 6405  The main character of the film is an outstandi...      13.131
# 6464  A young couple purchase their new home to star...       7.519
# 6467  A single man has worked most of his life in a ...       5.833
# 7462  After reading an article about hypnotic regres...       6.239
#
#                            poster_path release_date   title  video  \
# 4849                              None   2008-01-01  Return  False
# 5301                              None   1972-07-15  Return  False
# 5644  /v4F270SLg2HM89XzHV4i7o1UXyt.jpg   2015-07-04  Return  False
# 5874                              None   2020-01-28  Return  False
# 5981  /a3fhJx8oVTC1Mh9QraF1z2K1Wr1.jpg   2015-01-01  Return  False
# 5994  /xAuR564U2njKKcXSbfbq36rZLeA.jpg   2011-02-10  Return  False
# 6405                              None   1972-07-02  Return  False
# 6464  /rEnvFHITDcvKA7Gi9pD5FeCiEXy.jpg   2015-11-28  Return  False
# 6467                              None   2020-06-10  Return  False
# 7462  /54QOkHWUnn3gDZKfGojPiFqTHJD.jpg   1985-10-31  Return  False
#
#       vote_average  vote_count
# 4849         6.655         562
# 5301         6.555         301
# 5644         6.500         488
# 5874         6.441         506
# 5981         6.416         906
# 5994         6.415        3362
# 6405         6.300         548
# 6464         6.304         784
# 6467         6.303        1151
# 7462         6.066        1978

# %% [markdown]
# **All are not exactly duplicated.**

# %%
data.info()
data['release_date'] = pd.to_datetime(data['release_date'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9680 entries, 0 to 9679
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              9680 non-null   bool
#  1   backdrop_path      9671 non-null   object
#  2   genre_ids          9680 non-null   object
#  3   id                 9680 non-null   int64
#  4   original_language  9680 non-null   object
#  5   original_title     9680 non-null   object
#  6   overview           9680 non-null   object
#  7   popularity         9680 non-null   float64
#  8   poster_path        9675 non-null   object
#  9   release_date       9680 non-null   object
#  10  title              9680 non-null   object
#  11  video              9680 non-null   bool
#  12  vote_average       9680 non-null   float64
#  13  vote_count         9680 non-null   int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 926.5+ KB

# %%
data['release_date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# # Basic Text Preprocessing on `title` and `overview` columns

# %%
# !pip install emoji TextBlob nltk spacy

import pandas as pd
import numpy as np
import re
import spacy
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from textblob import TextBlob
import emoji

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Ensure NLTK stopwords are downloaded
import nltk
nltk.download('stopwords')

# Initialize the stemmer
stemmer = PorterStemmer()

# Step 1: Lowercasing
def lower_case(text):
    return text.lower()

# Step 2: Remove HTML tags
def remove_html(text):
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)

# Step 3: Remove URLs
def remove_urls(text):
    return re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)

# Step 4: Remove punctuation
def remove_punctuation(text):
    return re.sub(r'[^\w\s]', '', text)

# Step 5: Remove extra whitespace
def remove_whitespace(text):
    return re.sub(r'\s+', ' ', text).strip()

# Step 6: Correcting misspellings
def correct_spelling(text):
    return str(TextBlob(text).correct())

# Step 7: Handle emojis
def replace_emojis(text):
    return emoji.demojize(text)

# Step 8: Replace shorthand and abbreviations
def replace_shorthand(text):
    shorthand_dict = {
        "btw": "by the way",
        "lmao": "laughing my ass off",
        "omg": "oh my god",
        "brb": "be right back",
        "gr8": "great",
        "4": "for",
        "teh": "the",
        "u": "you",
        "r": "are",
        "c": "see",
        "b": "be"
    }
    for shorthand, full_form in shorthand_dict.items():
        text = re.sub(r'\b' + shorthand + r'\b', full_form, text)
    return text
author = 'Shuvendu pritam Das | 23mt0389@iitism.ac.in'
# Step 9: Tokenization using spaCy
def tokenize(text):
    doc = nlp(text)
    return [token.text for token in doc]

# Step 10: POS tagging and Parsing
def pos_and_parse(text):
    doc = nlp(text)
    pos_tags = [(token.text, token.pos_) for token in doc]
    parse_tree = [(token.text, token.dep_, token.head.text) for token in doc]
    return pos_tags, parse_tree

# Full Preprocessing Pipeline
def preprocess(text, use_lowercase=True, use_html_removal=True, use_url_removal=True,
              use_punctuation_removal=True, use_whitespace_removal=True,
              use_spelling_correction=True, use_emoji_handling=True,
              use_shorthand_replacement=True, use_stop_words=False,
              use_lemmatization=False, use_stemming=False):

    # Step 1: Lowercasing
    if use_lowercase:
        text = lower_case(text)

    # Step 2: Remove HTML tags
    if use_html_removal:
        text = remove_html(text)

    # Step 3: Remove URLs
    if use_url_removal:
        text = remove_urls(text)

    # Step 4: Remove punctuation
    if use_punctuation_removal:
        text = remove_punctuation(text)

    # Step 5: Remove extra whitespace
    if use_whitespace_removal:
        text = remove_whitespace(text)

    # Step 6: Correcting misspellings
    if use_spelling_correction:
        text = correct_spelling(text)

    # Step 7: Handle emojis
    if use_emoji_handling:
        text = replace_emojis(text)

    # Step 8: Replace shorthand and abbreviations
    if use_shorthand_replacement:
        text = replace_shorthand(text)

    # Tokenization using spaCy
    tokens = tokenize(text)

    # Use NLTK for stop words
    if use_stop_words:
        stop_words = set(stopwords.words('english'))
        tokens = [token for token in tokens if token not in stop_words]

    # Apply lemmatization if needed
    if use_lemmatization:
        tokens = [nlp(token)[0].lemma_ for token in tokens]  # Lemmatize each token

    # Apply stemming if needed
    if use_stemming:
        tokens = [stemmer.stem(token) for token in tokens]  # Stem each token

    # Get POS tags and parse tree
    pos_tags, parse_tree = pos_and_parse(text)

    return tokens, pos_tags, parse_tree

# Preprocess function for DataFrame input
def preprocess_dataframe(df, column_name, **kwargs):
    df['tokens'], df['pos_tags'], df['parse_tree'] = zip(
        *df[column_name].apply(lambda x: preprocess(x, **kwargs))
    )
    return df

# Preprocess the DataFrame
# processed_df = preprocess_dataframe(
#     df,
#     column_name='text',
#     use_lowercase=True,
#     use_html_removal=True,
#     use_url_removal=True,
#     use_punctuation_removal=True,
#     use_whitespace_removal=True,
#     use_spelling_correction=True,
#     use_emoji_handling=True,
#     use_shorthand_replacement=True,
#     use_stop_words=True,
#     use_lemmatization=True,
#     use_stemming=True
# )

# # Display the results
# print(processed_df[['text', 'tokens', 'pos_tags', 'parse_tree']])
# Out:
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Requirement already satisfied: TextBlob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.2)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = data.copy().head(25)
text = 'overview'

# %%
processed_df = preprocess_dataframe(
    df,
    column_name=text,
    use_lowercase=True,
    use_html_removal=True,
    use_url_removal=True,
    use_punctuation_removal=True,
    use_whitespace_removal=True,
    use_spelling_correction=True,
    use_emoji_handling=True,
    use_shorthand_replacement=True,
    use_stop_words=False,
    use_lemmatization=True,
    use_stemming=True
)

# Display the results
processed_df[[text, 'tokens', 'pos_tags', 'parse_tree']]
# Out:
#                                              overview  \
# 0   Imprisoned in the 1940s for the double murder ...
# 1   Spanning the years 1945 to 1955, a chronicle o...
# 2   After a shipwreck, an intelligent robot called...
# 3   In the continuing saga of the Corleone crime f...
# 4   The true story of how businessman Oskar Schind...
# 5   The defense and the prosecution have rested an...
# 6   A young girl, Chihiro, becomes trapped in a st...
# 7   Raj is a rich, carefree, happy-go-lucky second...
# 8   Batman raises the stakes in his war on crime. ...
# 9   All unemployed, Ki-taek's family takes peculia...
# 10  A supernatural tale set on death row in a Sout...
# 11  A burger-loving hit man, his philosophical par...
# 12  High schoolers Mitsuha and Taki are complete s...
# 13  As armies mass for a final battle that will de...
# 14  A man with a low IQ has accomplished great thi...
# 15  While the Civil War rages on between the Union...
# 16  The true story of Henry Hill, a half-Irish, ha...
# 17  A samurai answers a village's request for prot...
# 18  In the final months of World War II, 14-year-o...
# 19  A filmmaker recalls his childhood, when he fel...
# 20  A touching story of an Italian book seller of ...
# 21  The adventures of a group of explorers who mak...
# 22  A ticking-time-bomb insomniac and a slippery s...
# 23  When larcenous real estate clerk Marion Crane ...
# 24  After the death of her abusive husband, Matild...
#
#                                                tokens  \
# 0   [imprison, in, the, 1940, for, the, doubl, mur...
# 1   [span, the, year, 1945, to, 1955, a, chronicl,...
# 2   [after, a, shipwreck, an, intellig, root, call...
# 3   [in, the, continu, sage, of, the, corleon, cri...
# 4   [the, true, stori, of, how, businessman, oscar...
# 5   [the, defens, and, the, prosecut, have, rest, ...
# 6   [a, young, girl, chihiro, becom, wrap, in, a, ...
# 7   [run, be, a, rich, carefre, happygolucki, seco...
# 8   [batman, rais, the, stake, in, hi, war, on, cr...
# 9   [all, unemploy, kitaek, famili, take, peculiar...
# 10  [a, supernatur, tale, set, on, death, row, in,...
# 11  [a, burgerlov, hit, man, hi, philosoph, partne...
# 12  [high, school, misha, and, take, be, complet, ...
# 13  [as, armi, mass, for, a, final, battl, that, w...
# 14  [a, man, with, a, low, in, have, accomplish, g...
# 15  [while, the, civil, war, rage, on, between, th...
# 16  [the, true, stori, of, henri, hill, a, halfiri...
# 17  [a, samurai, answer, a, villag, request, for, ...
# 18  [in, the, final, month, of, world, war, ii, 14...
# 19  [a, filmmak, recal, hi, childhood, when, he, f...
# 20  [a, touch, stori, of, an, italian, book, selle...
# 21  [the, adventur, of, a, group, of, explor, who,...
# 22  [a, tickingtimebomb, insomnia, and, a, slipper...
# 23  [when, larcen, real, estat, clerk, marion, cra...
# 24  [after, the, death, of, her, abus, husband, ma...
#
#                                              pos_tags  \
# 0   [(imprisoned, VERB), (in, ADP), (the, DET), (1...
# 1   [(spanning, VERB), (the, DET), (years, NOUN), ...
# 2   [(after, ADP), (a, DET), (shipwreck, NOUN), (a...
# 3   [(in, ADP), (the, DET), (continuing, VERB), (s...
# 4   [(the, DET), (true, ADJ), (story, NOUN), (of, ...
# 5   [(the, DET), (defense, NOUN), (and, CCONJ), (t...
# 6   [(a, DET), (young, ADJ), (girl, NOUN), (chihir...
# 7   [(ran, VERB), (is, AUX), (a, DET), (rich, ADJ)...
# 8   [(batman, PROPN), (raises, VERB), (the, DET), ...
# 9   [(all, DET), (unemployed, ADJ), (kitaeks, PROP...
# 10  [(a, DET), (supernatural, ADJ), (tale, NOUN), ...
# 11  [(a, DET), (burgerloving, VERB), (hit, VERB), ...
# 12  [(high, ADJ), (schools, NOUN), (misha, PROPN),...
# 13  [(as, SCONJ), (armies, NOUN), (mass, VERB), (f...
# 14  [(a, DET), (man, NOUN), (with, ADP), (a, DET),...
# 15  [(while, SCONJ), (the, DET), (civil, ADJ), (wa...
# 16  [(the, DET), (true, ADJ), (story, NOUN), (of, ...
# 17  [(a, DET), (samurai, NOUN), (answers, VERB), (...
# 18  [(in, ADP), (the, DET), (final, ADJ), (months,...
# 19  [(a, DET), (filmmaker, NOUN), (recalls, VERB),...
# 20  [(a, DET), (touching, ADJ), (story, NOUN), (of...
# 21  [(the, DET), (adventures, NOUN), (of, ADP), (a...
# 22  [(a, DET), (tickingtimebomb, NOUN), (insomnia,...
# 23  [(when, SCONJ), (larcenous, ADJ), (real, ADJ),...
# 24  [(after, ADP), (the, DET), (death, NOUN), (of,...
#
#                                            parse_tree
# 0   [(imprisoned, advcl, begins), (in, prep, impri...
# 1   [(spanning, csubj, survives), (the, det, years...
# 2   [(after, prep, is), (a, det, shipwreck), (ship...
# 3   [(in, prep, grows), (the, det, sage), (continu...
# 4   [(the, det, story), (true, amod, story), (stor...
# 5   [(the, det, defense), (defense, nsubj, rested)...
# 6   [(a, det, chihiro), (young, amod, girl), (girl...
# 7   [(ran, csubj, is), (is, ROOT, is), (a, det, ca...
# 8   [(batman, nsubj, raises), (raises, ROOT, raise...
# 9   [(all, det, family), (unemployed, amod, kitaek...
# 10  [(a, det, tale), (supernatural, amod, tale), (...
# 11  [(a, det, man), (burgerloving, amod, man), (hi...
# 12  [(high, amod, schools), (schools, compound, mi...
# 13  [(as, mark, mass), (armies, nsubj, mass), (mas...
# 14  [(a, det, man), (man, nsubj, accomplished), (w...
# 15  [(while, mark, rages), (the, det, rages), (civ...
# 16  [(the, det, story), (true, amod, story), (stor...
# 17  [(a, det, samurai), (samurai, nsubj, answers),...
# 18  [(in, prep, are), (the, det, months), (final, ...
# 19  [(a, det, filmmaker), (filmmaker, nsubj, recal...
# 20  [(a, det, story), (touching, amod, story), (st...
# 21  [(the, det, adventures), (adventures, ROOT, ad...
# 22  [(a, det, insomnia), (tickingtimebomb, compoun...
# 23  [(when, advmod, goes), (larcenous, amod, crane...
# 24  [(after, prep, finds), (the, det, death), (dea...
