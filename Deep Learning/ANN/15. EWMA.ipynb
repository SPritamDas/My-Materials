# %% [markdown]
# # **Exponential Moving Average**
# ---
#
#
# ### 🧑‍💼 **Shuvendu Pritam Das**
# *Data Science / ML Enthusiast*
#
# - **GitHub:** [SPritamDas](https://github.com/SPritamDas/My-Profile)
# - **LinkedIn:** [Shuvendu Pritam Das](https://www.linkedin.com/in/shuvendupritamdas/)
# - **Email:** shuvendupritamdas181@gmail.com
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'/content/drive/MyDrive/Portfolio/100 DAYS OF DL/DailyDelhiClimateTrain.csv')
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df = df[['date','meantemp']]

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['date'], df['meantemp'])

# %%
x1 = df['meantemp'].ewm(alpha=0.1).mean()

# %%
df['ewma']=x1

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['date'], df['meantemp'])
plt.plot(df['date'],df['ewma'],color = 'red')

# %%
for i in (np.arange(0.1,1,0.1)):
  x1 = df['meantemp'].ewm(alpha = float(i)).mean()
  plt.figure(figsize=(10,5))
  plt.scatter(df['date'], df['meantemp'])
  plt.plot(df['date'],x1,color = 'red')
  plt.title(f'Alpha = {i}')
  plt.show()
